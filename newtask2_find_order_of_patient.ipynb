# %% [markdown]
# <a href="https://colab.research.google.com/github/kasame62/find-shortest-path/blob/main/newtask2_find_order_of_patient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
from matplotlib import pyplot as plt

G = nx.grid_2d_graph(6,6)

plt.figure(figsize=(6,6))
pos = {(x,y):(y,-x) for x,y in G.nodes()}
nx.draw(G, pos=pos, 
        node_color='lightgreen', 
        with_labels=True,
        node_size=600)

# %%
coor1 = (0, 2) # seen as 2 in the arr array
coor2 = (2, 1) # seen as 7 in the arr array

nx.bidirectional_shortest_path(G, source=coor1, target=coor2)
# Out:
# [(0, 2), (1, 2), (2, 2), (2, 1)]
